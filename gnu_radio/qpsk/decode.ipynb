# %%
fh = open("tx_data.bin","rb")

NUM_SAMPLES = 1

byte = fh.read(16)

for sample_idx in range(NUM_SAMPLES):
    # print(ord(byte),end=" ")
    print(byte)
    byte = fh.read(16)

fh.close()
# Out:
# b'\x03\x00\x02\x02\x02\x00\x03\x01\x01\x03\x01\x03\x03\x02\x03\x01'

# %%
fh = open("rx_data.bin","rb")

NUM_SAMPLES = 16

byte = fh.read(NUM_SAMPLES)

START_IDX = 1024

for i in range(1024 + 16):
    
    # for sample_idx in range(NUM_SAMPLES):

    #     if(i >= START_IDX):
    #         print(ord(byte),end=" ")
    #     byte = fh.read(1)

    # if(i >= START_IDX):
    #     print()
    

    if(i >= START_IDX):
        print(byte)

    byte = fh.read(NUM_SAMPLES)
    


fh.close()
# Out:
# b'\x01\x01\x01\x01\x00\x00\x00\x00\x03\x03\x03\x03\x03\x03\x03\x03'
# b'\x01\x01\x01\x01\x02\x02\x02\x02\x03\x03\x03\x03\x01\x01\x01\x01'
# b'\x02\x02\x02\x02\x00\x00\x00\x00\x02\x02\x02\x02\x01\x01\x01\x01'
# b'\x03\x03\x03\x03\x00\x00\x00\x00\x02\x02\x02\x02\x02\x02\x02\x02'
# b'\x01\x01\x01\x01\x00\x00\x00\x00\x03\x03\x03\x03\x03\x03\x03\x03'
# b'\x01\x01\x01\x01\x02\x02\x02\x02\x03\x03\x03\x03\x01\x01\x01\x01'
# b'\x02\x02\x02\x02\x00\x00\x00\x00\x02\x02\x02\x02\x01\x01\x01\x01'
# b'\x03\x03\x03\x03\x00\x00\x00\x00\x02\x02\x02\x02\x02\x02\x02\x02'
# b'\x01\x01\x01\x01\x00\x00\x00\x00\x03\x03\x03\x03\x03\x03\x03\x03'
# b'\x01\x01\x01\x01\x02\x02\x02\x02\x03\x03\x03\x03\x01\x01\x01\x01'
# b'\x02\x02\x02\x02\x00\x00\x00\x00\x02\x02\x02\x02\x01\x01\x01\x01'
# b'\x03\x03\x03\x03\x00\x00\x00\x00\x02\x02\x02\x02\x02\x02\x02\x02'
# b'\x01\x01\x01\x01\x00\x00\x00\x00\x03\x03\x03\x03\x03\x03\x03\x03'
# b'\x01\x01\x01\x01\x02\x02\x02\x02\x03\x03\x03\x03\x01\x01\x01\x01'
# ...
