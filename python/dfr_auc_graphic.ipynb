# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Creating dataset
n = 100
# x = np.random.standard_normal(n)
y = 3.0 * x

# %%
z = np.array([0.797,0.778,0.742,0.544,0.541,0.492,0.512,0.513,0.512,
0.797,0.778,0.742,0.667,0.571,0.513,0.494,0.516,0.534,
0.797,0.779,0.746,0.662,0.608,0.479,0.507,0.513,0.531,
0.795,0.774,0.745,0.66,0.622,0.506,0.496,0.531,0.546,
0.791,0.775,0.747,0.662,0.631,0.494,0.5,0.523,0.559,
0.791,0.777,0.748,0.663,0.64,0.483,0.492,0.549,0.535,
0.796,0.776,0.747,0.665,0.644,0.505,0.487,0.532,0.556,
0.794,0.778,0.744,0.666,0.636,0.496,0.492,0.533,0.565,
0.788,0.779,0.745,0.666,0.628,0.489,0.493,0.527,0.552]).reshape((9,9))

x = np.arange(0.1,1,0.1)
y = np.arange(0.1,1,0.1)

# %%
fig = plt.figure(figsize=(8,8))

plt.pcolormesh(x,y,z,shading="gouraud")
plt.colorbar()

plt.title('Spectrum Sensing AUC Values (N = 10)', fontweight ="bold")
plt.xlabel("W_in")
plt.ylabel("W_fb")

plt.show()
